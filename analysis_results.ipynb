# %%
from config import *
from ngnet.ngram import NGram
from ngnet.wordnet import WordNet
from analysis import analysis_1, analysis_2, analysis_3, analysis_4, analysis_5
# %matplotlib inline

# %%
# initialize
mygram = NGram(NGRAMS_LOWER_ALPHA, TOTAL_COUNT)
minigram = NGram(NGRAMS_MINI, TOTAL_COUNT)
mynet = WordNet(SYNSETS, HYPONYMS)

# %%
# 1
analysis_1.plot_wl(mygram)

# %%
# 2
analysis_2.plot_comparison(mygram, ['socialism', 'capitalism'])

# %%
# 3
analysis_3.plot_hyponyms(mynet, mygram)

# %%
# 4 
analysis_4.boxplot_hyponyms(mynet, mygram, ['earth', 'air', 'fire', 'water'])

# %%
# 5
analysis_5.plot_count_vs_rank(mygram)
